# %%
from PIL import Image
import numpy as np

# %%
image_path = "./231.png"
pixel_coordinates = (45, 120)  # in your code it is X, Y

# %%
img = Image.open(image_path)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (256, 256, 3)

# %%
x, y = pixel_coordinates
x
# Out:
# 45

# %%
img_array[x, y]
# Out:
# array([122, 123,  83], dtype=uint8)

# %%
R,G,B = img_array[x, y]

# %%
R
# Out:
# 122
